# %%
import pandas as pd
import numpy as np

# %%
dataFrame = pd.DataFrame(np.random.randint(2000,size=(51,4)),columns =['a','b','c','d'])

# %%
dataFrame
# Out:
#        a     b     c     d
# 0    411   130   403   316
# 1   1822   303   474    20
# 2   1028   284   418  1968
# 3   1281  1131   913  1659
# 4    813   806   569   609
# 5   1836   939  1145   431
# 6    790   378  1260  1696
# 7    955   208   557   144
# 8   1206  1053  1400  1499
# 9   1102  1637  1734  1131
# 10   857   322   612   899
# 11  1550   858   194  1221
# 12  1046  1162  1568   717
# 13  1370    45   766   929
# 14   704   365   643  1630
# 15  1056   367    18   442
# 16  1759  1228   740  1583
# 17  1594   961  1089   993
# 18   866  1052   367  1711
# 19  1945  1517   244  1578
# 20   500  1306  1021   177
# 21   442  1468   567  1528
# 22   185  1110  1698   193
# 23  1133  1850  1661   493
# 24  1267   964   155  1877
# 25  1120   351  1402   385
# 26  1277  1286   285  1622
# 27  1120  1468   665  1529
# 28   573   264  1657     0
# 29   672  1628  1741    10
# 30  1850  1442  1861  1854
# 31  1050  1112  1960  1885
# 32  1250   940   672   338
# ...

# %%
dataFrame['a'].hist()
# Out:
# <Axes: >

# %%
dataFrame['b'].hist(bins=30)
# Out:
# <Axes: >

# %%
dataFrame.plot.area()
# Out:
# <Axes: >
