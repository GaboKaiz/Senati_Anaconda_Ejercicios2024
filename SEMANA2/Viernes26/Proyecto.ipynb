# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("medallas.csv")

# %%
df
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0    NaN    1.0     2.0      3     Argentina
# 1    NaN    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    NaN    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   NaN    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]

# %%
df.shape
# Out:
# (93, 5)

# %%
df.columns
# Out:
# Index(['Oro', 'Plata', 'Bronce', 'Total', 'Pais'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Oro     65 non-null     float64
#  1   Plata   69 non-null     float64
#  2   Bronce  76 non-null     float64
#  3   Total   93 non-null     int64
#  4   Pais    93 non-null     object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
#3
df.isnull()
# Out:
#       Oro  Plata  Bronce  Total   Pais
# 0    True  False   False  False  False
# 1    True  False   False  False  False
# 2   False  False   False  False  False
# 3   False  False   False  False  False
# 4    True  False   False  False  False
# ..    ...    ...     ...    ...    ...
# 88   True  False    True  False  False
# 89  False  False   False  False  False
# 90  False  False   False  False  False
# 91  False   True   False  False  False
# 92  False  False    True  False  False
#
# [93 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Oro       28
# Plata     24
# Bronce    17
# Total      0
# Pais       0
# dtype: int64

# %%
df_eliminados= df.dropna()
df_eliminados
# Out:
#      Oro  Plata  Bronce  Total                        Pais
# 2   17.0    7.0    22.0     46                   Australia
# 3    1.0    1.0     5.0      7                     Austria
# 7    1.0    3.0     3.0      7                     Belarus
# 8    3.0    1.0     3.0      7                     Belgium
# 11   7.0    6.0     8.0     21                      Brazil
# 12   3.0    1.0     2.0      6                    Bulgaria
# 14   7.0    6.0    11.0     24                      Canada
# 15   2.0    4.0     6.0     12              Chinese Taipei
# 17   3.0    3.0     2.0      8                     Croatia
# 19   7.0    3.0     5.0     15                        Cuba
# 20   4.0    4.0     3.0     11              Czech Republic
# 21   3.0    4.0     4.0     11                     Denmark
# 24   1.0    1.0     4.0      6                       Egypt
# 25  39.0   41.0    33.0    113   Estados Unidos de America
# 27   1.0    1.0     2.0      4                    Ethiopia
# ...

# %%
df['Pais']
# Out:
# 0        Argentina
# 1          Armenia
# 2        Australia
# 3          Austria
# 4       Azerbaijan
#           ...
# 88    Turkmenistan
# 89          Uganda
# 90         Ukraine
# 91      Uzbekistan
# 92       Venezuela
# Name: Pais, Length: 93, dtype: object

# %%
valores_nuevos = {"Oro":15}
df_rellenados = df.fillna(valores_nuevos)
df_rellenados
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0   15.0    1.0     2.0      3     Argentina
# 1   15.0    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4   15.0    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88  15.0    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]

# %%
medallas = df.groupby('Pais')['Oro'].sum().reset_index()
medallas_pais = medallas.sort_values(by='Oro', ascending=False).head(3)
medallas_pais
# Out:
#                           Pais   Oro
# 25   Estados Unidos de America  39.0
# 73  Republica Popular de China  38.0
# 46                       Japon  27.0

# %%
medallas2 = df.groupby('Pais').sum()
paises_con_10M = medallas2[medallas2['Total']>10]
paises_con_10M.sort_values(by='Total', ascending=False)
# Out:
#                              Oro  Plata  Bronce  Total
# Pais
# Estados Unidos de America   39.0   41.0    33.0    113
# Republica Popular de China  38.0   32.0    18.0     88
# ROC                          2.0   28.0    23.0     71
# Gran Bretana                22.0   21.0    22.0     65
# Japon                       27.0   14.0    17.0     58
# Australia                   17.0    7.0    22.0     46
# Germany                      1.0   11.0    16.0     37
# Netherlands                  1.0   12.0    14.0     36
# France                       1.0   12.0    11.0     33
# Canada                       7.0    6.0    11.0     24
# Brazil                       7.0    6.0     8.0     21
# Ukraine                      1.0    6.0    12.0     19
# Spain                        3.0    8.0     6.0     17
# Cuba                         7.0    3.0     5.0     15
# Poland                       4.0    5.0     5.0     14
# Switzerland                  3.0    4.0     6.0     13
# ...
