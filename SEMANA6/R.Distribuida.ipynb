# %%
#Representación distribuida DISPLOT()
import seaborn as sns

# %%
pinguinos = sns.load_dataset("penguins")
pinguinos.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=pinguinos,
           x = "body_mass_g",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True,
            #COL: Comparación con otro atributo ? ISLAS
            col = "island",
           );

# %%
#RUGPLOT:
sns.displot(data=pinguinos,
           x = "flipper_length_mm",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
sns.rugplot(data=pinguinos, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm'>

# %%
import seaborn as sns; sns.set_theme()
tips = sns.load_dataset("tips")
sns.kdeplot(data=pinguinos, x="flipper_length_mm")
sns.rugplot(data=pinguinos, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(data=pinguinos,
           x = "bill_length_mm",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
sns.displot(data=pinguinos,
           x = "sex",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
sns.displot(data=pinguinos,
           x = "bill_depth_mm",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
sns.displot(data=pinguinos,
           x = "island",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
sns.displot(data=pinguinos,
           x = "species",
            #KDE: Representación de la densidad de la probabilidad estimada (Picos)
            kde = True
           );

# %%
#RUGPLOT:
sns.displot(data=pinguinos,
           x = "flipper_length_mm",
            kind = "kde",
            rug = True);
