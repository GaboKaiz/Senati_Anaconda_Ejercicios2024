# %%
#Importamos matplotlib
import matplotlib.pyplot as plt

# %%
numeros = [10,20,30,40,50,60]
# %matplotlib inline
plt.plot(numeros)
#Guardamos el gráfico generado por la lista y lo guardamos con savefig y entre parentesis un nombre para guardar.
plt.savefig("mi_grafico.png")
plt.show()

# %%
#Importamos matplotlib
import matplotlib.pyplot as plt

# %%
numeros = [10,20,30,35,20,15]
# %matplotlib inline
#Figura 
plt.figure(facecolor="Yellow")
plt.plot(numeros);
#Los axes son los ejes X, Y:
plt.subplots(ncols=2,nrows=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))
